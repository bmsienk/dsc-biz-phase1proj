# %% [markdown]
# # Project Title
#
# **Authors:** Brandon Sienkiewicz, Ilan Haskel, Zach Cherna

# %% [markdown]
# ## Overview
#
# ## Business Problem

# %% [markdown]
# ## Data Understanding

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns

conn = sqlite3.connect('zippedData/im.db')
# %matplotlib inline

# %%
df1 = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
df2 = pd.read_csv('zippedData/rt.movie_info.tsv.gz', sep = "\t")
df3 = pd.read_csv('zippedData/rt.reviews.tsv.gz', sep = "\t", encoding = 'latin1')
df4 = pd.read_csv('zippedData/tmdb.movies.csv.gz')
df5 = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
df6 = pd.read_sql("""
SELECT *
FROM movie_basics b
JOIN movie_ratings r
ON b.movie_id = r.movie_id
""", conn)

# %% [markdown]
# ## Data Preparation

# %%
df1
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %% [markdown]
# ## Data Modeling

# %%
df2
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Conclusion

# %%
df5
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
df6
# Out:
#         movie_id                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
#        start_year  runtime_minutes                genres   movie_id  \
# 0            2013            175.0    Action,Crime,Drama  tt0063540
# 1            2019            114.0       Biography,Drama  tt0066787
# 2            2018            122.0                 Drama  tt0069049
# 3            2018              NaN          Comedy,Drama  tt0069204
# 4            2017             80.0  Comedy,Drama,Fantasy  tt0100275
# ...           ...              ...                   ...        ...
# 73851        2019             75.0           Documentary  tt9913084
# 73852        2019             98.0          Drama,Family  tt9914286
# 73853        2017              NaN           Documentary  tt9914642
# 73854        2019              NaN                  None  tt9914942
# 73855        2019             72.0           Documentary  tt9916160
#
#        averagerating  numvotes
# 0                7.0        77
# 1                7.2        43
# 2                6.9      4517
# 3                6.1        13
# 4                6.5       119
# ...              ...       ...
# 73851            6.2         6
# 73852            8.7       136
# 73853            8.5         8
# 73854            6.6         5
# 73855            6.5        11
#
# [73856 rows x 9 columns]

# %%
df5 = df5.drop(columns = ['id'])

# %%
df6 = df6.drop(columns = ['movie_id', 'original_title', 'movie_id'])

# %%
df5 = df5[df5['movie'].isin(list(df6['primary_title']))]
df6 = df6[df6['primary_title'].isin(df5['movie'])]

# %%
df5['movie'].value_counts()[:60]
# Out:
# Halloween                       3
# Home                            3
# Ghostbusters                    2
# Side Effects                    2
# Dangerous Liaisons              2
# Conan the Barbarian             2
# Ca$h                            2
# Night of the Living Dead        2
# The Great Gatsby                2
# Footloose                       2
# Trance                          2
# The Mummy                       2
# Crossroads                      2
# Brothers                        2
# Venom                           2
# Death at a Funeral              2
# Flatliners                      2
# Aladdin                         2
# Carrie                          2
# The Island                      2
# Ben-Hur                         2
# Beauty and the Beast            2
# Legend                          2
# Hercules                        2
# Point Break                     2
# Cinderella                      2
# The Gambler                     2
# Serenity                        2
# Poltergeist                     2
# The Signal                      2
# A Nightmare on Elm Street       2
# The Jungle Book                 2
# The Calling                     2
# Hellboy                         2
# Snitch                          2
# Pet Sematary                    2
# Godzilla                        2
# Alice in Wonderland             2
# The Square                      2
# Clash of the Titans             2
# Unforgettable                   2
# Fantastic Four                  2
# Total Recall                    2
# The Avengers                    2
# Unknown                         2
# Life                            2
# Left Behind                     2
# Pinocchio                       2
# The Gift                        2
# RoboCop                         2
# Robin Hood                      2
# The Birth of a Nation           2
# Hamlet                          2
# Teenage Mutant Ninja Turtles    2
# Heist                           2
# The Karate Kid                  2
# Manchester by the Sea           1
# Posledniy bogatyr               1
# Easy A                          1
# Limbo                           1
# Name: movie, dtype: int64

# %%
df6 = df6.rename(columns={'primary_title' : 'movie'})

# %%
df6['movie'].value_counts()[:100]
# Out:
# The Return              11
# Brothers                 8
# The Gift                 8
# Home                     8
# One Day                  6
#                         ..
# Butterfly                3
# Stronger                 3
# August                   3
# All You Need Is Love     3
# Dragonfly                3
# Name: movie, Length: 100, dtype: int64

# %%
df5['year'] = pd.DatetimeIndex(df5['release_date']).year
df5 = df5.drop(columns='release_date')

# %%
df5['unique'] = df5['movie'].str.cat(df5['year'].astype(str), sep = ' ')
df6['unique'] = df6['movie'].str.cat(df6['start_year'].astype(str), sep = ' ')
df5
# Out:
#                                             movie production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 6                          Avengers: Infinity War      $300,000,000
# ...                                           ...               ...
# 5761                         Stories of Our Lives           $15,000
# 5767                                         Cure           $10,000
# 5772                                    Newlyweds            $9,000
# 5777                                       Red 11            $7,000
# 5780                         A Plague So Pleasant            $1,400
#
#      domestic_gross worldwide_gross  year  \
# 0      $760,507,625  $2,776,345,279  2009
# 1      $241,063,875  $1,045,663,875  2011
# 2       $42,762,350    $149,762,350  2019
# 3      $459,005,868  $1,403,013,963  2015
# 6      $678,815,482  $2,048,134,200  2018
# ...             ...             ...   ...
# 5761             $0              $0  2014
# 5767        $94,596         $94,596  2001
# 5772         $4,584          $4,584  2012
# 5777             $0              $0  2018
# 5780             $0              $0  2015
#
#                                                 unique
# 0                                          Avatar 2009
# 1     Pirates of the Caribbean: On Stranger Tides 2011
# 2                                    Dark Phoenix 2019
# 3                         Avengers: Age of Ultron 2015
# 6                          Avengers: Infinity War 2018
# ...                                                ...
# 5761                         Stories of Our Lives 2014
# 5767                                         Cure 2001
# 5772                                    Newlyweds 2012
# 5777                                       Red 11 2018
# 5780                         A Plague So Pleasant 2015
#
# [2184 rows x 6 columns]

# %%
df5 = df5[df5['unique'].isin(list(df6['unique']))]
df6 = df6[df6['unique'].isin(df5['unique'])]
df6['unique'].value_counts()
df6=df6.sort_values(by='numvotes', ascending=False)
df6 = df6.drop_duplicates(subset='unique')

# %%
df_new = pd.merge(df5,df6)
df_new.corr()
# Out:
#                    production_budget  domestic_gross  worldwide_gross  \
# production_budget           1.000000        0.711554         0.785485
# domestic_gross              0.711554        1.000000         0.945085
# worldwide_gross             0.785485        0.945085         1.000000
# year                        0.063848        0.084190         0.092439
# start_year                  0.063848        0.084190         0.092439
# runtime_minutes             0.375025        0.318571         0.329017
# averagerating               0.226273        0.328727         0.310343
# numvotes                    0.549558        0.668699         0.656622
#
#                        year  start_year  runtime_minutes  averagerating  \
# production_budget  0.063848    0.063848         0.375025       0.226273
# domestic_gross     0.084190    0.084190         0.318571       0.328727
# worldwide_gross    0.092439    0.092439         0.329017       0.310343
# year               1.000000    1.000000         0.126804       0.029969
# start_year         1.000000    1.000000         0.126804       0.029969
# runtime_minutes    0.126804    0.126804         1.000000       0.408142
# averagerating      0.029969    0.029969         0.408142       1.000000
# numvotes          -0.103798   -0.103798         0.428105       0.499399
#
#                    numvotes
# production_budget  0.549558
# domestic_gross     0.668699
# worldwide_gross    0.656622
# year              -0.103798
# start_year        -0.103798
# runtime_minutes    0.428105
# averagerating      0.499399
# numvotes           1.000000

# %%
sns.lmplot(x='production_budget', y='averagerating', data=df_new);

# %%
df5['production_budget']=df5['production_budget'].replace('[\$,]', '', regex=True).astype(float)
df5['worldwide_gross']=df5['worldwide_gross'].replace('[\$,]', '', regex=True).astype(float)
df5['domestic_gross']=df5['domestic_gross'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# C:\Users\bmsie\AppData\Local\Temp\ipykernel_12800\1870242210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['production_budget']=df5['production_budget'].replace('[\$,]', '', regex=True).astype(float)
# C:\Users\bmsie\AppData\Local\Temp\ipykernel_12800\1870242210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['worldwide_gross']=df5['worldwide_gross'].replace('[\$,]', '', regex=True).astype(float)
# C:\Users\bmsie\AppData\Local\Temp\ipykernel_12800\1870242210.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['domestic_gross']=df5['domestic_gross'].replace('[\$,]', '', regex=True).astype(float)

# %%
df5.plot('production_budget', 'worldwide_gross', kind='scatter');

# %%
df5.corr()
# Out:
#                    production_budget  domestic_gross  worldwide_gross  \
# production_budget           1.000000        0.711554         0.785485
# domestic_gross              0.711554        1.000000         0.945085
# worldwide_gross             0.785485        0.945085         1.000000
# year                        0.063848        0.084190         0.092439
#
#                        year
# production_budget  0.063848
# domestic_gross     0.084190
# worldwide_gross    0.092439
# year               1.000000

# %%
sns.lmplot(x='production_budget', y='worldwide_gross', data=df5);

# %%
sns.lmplot(x='production_budget', y='domestic_gross', data=df5);

# %%
df4=df4[df4['vote_count']>3000]
sns.lmplot(x='vote_average', y='vote_count', data=df4);

# %%
df1['studio'].value_counts()
# Out:
# IFC           166
# Uni.          147
# WB            140
# Fox           136
# Magn.         136
#              ...
# E1              1
# PI              1
# ELS             1
# PalT            1
# Synergetic      1
# Name: studio, Length: 257, dtype: int64
